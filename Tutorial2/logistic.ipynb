# %%
import pandas as pd

# %%
df=pd.read_csv('Cancer_Data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Data Preporocessing
# Removing the Column with all NaN values , and dropping rows which has any null values

# %%
df.drop('Unnamed: 32', axis=1, inplace=True)
df.dropna()
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# #### Taking features in X and output Varibale as Y

# %%
X=df.drop('diagnosis',axis=1)
Y=df['diagnosis']

# %% [markdown]
# #### Splitting the data into 80% training and 20% testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform Ytrain and Ttest to convert 'M' and 'B' to 0 and 1
Ytrain_encoded = label_encoder.fit_transform(Ytrain)
Ytest_encoded = label_encoder.fit_transform(Ytest)

# %%
Xtrain.shape
# Out:
# (455, 31)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(Xtrain, Ytrain_encoded)
# Out:
# /home/cosign/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(Xtest)

# %%
y_prob = model.predict_proba(Xtest)[:, 1]

# %% [markdown]
# #### Calculating Accuracy of the model

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Ytest_encoded, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9210526315789473

# %% [markdown]
# #### Calculating the precision, Recall , F1 score ,ROC-AOC

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, roc_curve
precision = precision_score(Ytest_encoded, y_pred)
recall = recall_score(Ytest_encoded, y_pred)
f1 = f1_score(Ytest_encoded, y_pred)
roc_auc = roc_auc_score(Ytest_encoded,  y_pred)

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("ROC-AUC:", roc_auc)
# Out:
# Precision: 0.9230769230769231
# Recall: 0.8571428571428571
# F1-score: 0.8888888888888888
# ROC-AUC: 0.9077380952380953

# %% [markdown]
# #### Plotting the Confusion Matrix

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Ytest_encoded, y_pred)
print(cm)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# [[69  3]
#  [ 6 36]]

# %% [markdown]
# #### Plotting the ROC curve

# %%
fpr, tpr, thresholds = roc_curve(Ytest_encoded, y_prob)
plt.figure()
plt.plot(fpr, tpr, color='blue', label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Cross validation
# Experimenting model with different training and testing data

# %%
import warnings
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Define the Logistic Regression model with default hyperparameters
model = LogisticRegression(max_iter=1000)

# Perform cross-validation with 5 folds
cv_scores = cross_val_score(model, Xtrain, Ytrain_encoded, cv=5, scoring='accuracy')

# Print the accuracy for each fold
print(f"Cross-validation scores: {cv_scores}")

# Calculate the average cross-validation score
mean_cv_score = cv_scores.mean()
print(f"Mean cross-validation accuracy: {mean_cv_score * 100:.2f}%")

# Train the final model on the entire training set
model.fit(Xtrain, Ytrain_encoded)

# Make predictions on the test data
y_pred = model.predict(Xtest)

# Evaluate the model's accuracy on the test data
accuracy = accuracy_score(Ytest_encoded, y_pred)
print(f"Accuracy of the model on test data: {accuracy * 100:.2f}%")
# Out:
# Cross-validation scores: [0.89010989 0.9010989  0.92307692 0.95604396 0.92307692]
# Mean cross-validation accuracy: 91.87%
# Accuracy of the model on test data: 92.11%

# %% [markdown]
# #### HyperParameters

# %%
import warnings
from sklearn.model_selection import GridSearchCV

# Define the hyperparameter grid
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],        # Regularization strength
    'penalty': ['l1', 'l2'],              # L1 or L2 regularization
    'solver': ['liblinear', 'saga']       # Solvers that support l1 and l2
}


# Perform grid search to tune hyperparameters
grid_search = GridSearchCV(LogisticRegression(max_iter=1000), param_grid, cv=10)
grid_search.fit(Xtrain, Ytrain_encoded)

# Best hyperparameters
print(f"Best Parameters: {grid_search.best_params_}")
# Out:
# /home/cosign/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cosign/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cosign/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cosign/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cosign/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
best_params = grid_search.best_params_

# Train a new Logistic Regression model with the best hyperparameters
best_model = LogisticRegression(
    C=best_params['C'], 
    penalty=best_params['penalty'], 
    solver=best_params['solver'], 
    max_iter=1000
)

# Fit the model on the training data
best_model.fit(Xtrain, Ytrain_encoded)

# Make predictions on the test data
y_pred_best = best_model.predict(Xtest)

# Evaluate the model's accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Ytest_encoded, y_pred_best)
print(f"Accuracy of the model with tuned hyperparameters: {accuracy * 100:.2f}%")
# Out:
# Accuracy of the model with tuned hyperparameters: 96.49%

# %% [markdown]
# #### Feature Importance

# %%
feature_importance = best_model.coef_[0]
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importance})
feature_importance_df.sort_values(by='Importance', ascending=False, inplace=True)
print(feature_importance_df)
# Out:
#                     Feature    Importance
# 8       concave points_mean  1.065554e+02
# 28     concave points_worst  3.133885e+01
# 29           symmetry_worst  1.964674e+01
# 27          concavity_worst  1.288013e+01
# 25         smoothness_worst  7.943671e+00
# 11                radius_se  8.105990e-01
# 22            texture_worst  2.140759e-01
# 2              texture_mean  1.763619e-01
# 14                  area_se  1.268994e-01
# 24               area_worst  2.121620e-02
# 23          perimeter_worst  8.987768e-03
# 0                        id  3.102646e-09
# 10   fractal_dimension_mean  0.000000e+00
# 7            concavity_mean  0.000000e+00
# 5           smoothness_mean  0.000000e+00
# 18        concave points_se  0.000000e+00
# 19              symmetry_se  0.000000e+00
# 30  fractal_dimension_worst  0.000000e+00
# 20     fractal_dimension_se  0.000000e+00
# 15            smoothness_se  0.000000e+00
# 4                 area_mean -1.199859e-03
# ...

# %% [markdown]
# #### Making model with important features only

# %%
# Step 1: Get feature importance from the best model and filter out the ones with negative importance
feature_importance = best_model.coef_[0]
feature_importance_df = pd.DataFrame({'Feature': Xtrain.columns, 'Importance': feature_importance})

# Filter out the features with negative importance
positive_features = feature_importance_df[feature_importance_df['Importance'] > 0]['Feature']

# Step 2: Filter the training and testing data to include only positive importance features
Xtrain_filtered = Xtrain[positive_features]
Xtest_filtered = Xtest[positive_features]

# Step 3: Train a new Logistic Regression model using the filtered data
best_params = grid_search.best_params_

best_model_filtered = LogisticRegression(
    C=best_params['C'], 
    penalty=best_params['penalty'], 
    solver=best_params['solver'], 
    max_iter=1000
)

# Fit the model on the filtered training data
best_model_filtered.fit(Xtrain_filtered, Ytrain_encoded)

# Step 4: Make predictions on the filtered test data
y_pred_best_filtered = best_model_filtered.predict(Xtest_filtered)

# Step 5: Evaluate the model's accuracy
accuracy_filtered = accuracy_score(Ytest_encoded, y_pred_best_filtered)
print(f"Accuracy of the model with features of positive importance: {accuracy_filtered * 100:.2f}%")
# Out:
# Accuracy of the model with features of positive importance: 97.37%
